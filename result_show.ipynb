# %%
import numpy as np
from matplotlib import pyplot as plt
from util.color import red_transparent_blue
import sys
import torch

# %%
img_ID = 1

# %%
exp_result = np.load(f'./scores_{img_ID}.npy')
exp_result.shape
# Out:
# (1, 200, 14, 14)

# %%
plt.figure
plt.imshow(exp_result[0,70], cmap=red_transparent_blue)
